# %% [markdown]
# # Employee Attrition Analysis

# %% [markdown]
# ##

# %%
import matplotlib.pyplot as plt             
from tabulate import tabulate               
import matplotlib as mat                     
import seaborn as sns                       
import pandas as pd                         
import numpy as np

# %%
data = pd.read_csv("DS1_C5_S1_EmployeeAttrition_Data_Practice.csv")

# %% [markdown]
# ####

# %% [markdown]
# ## TASK - 1 :

# %% [markdown]
# ### Display the basic information about the dataset, which includes column names, count of non-null records, and data type of the columns. Also, Display the count of missing values for each column.

# %% [markdown]
# #### Reading Top 5 rows

# %%
data.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %% [markdown]
# #### Reading Last 5 rows.

# %%
data.tail()
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %% [markdown]
# #### Checking Number of rows and columns in data.

# %%
data.shape
# Out:
# (1470, 27)

# %% [markdown]
# #### Information about dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %% [markdown]
# #### Column Names

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #### Count of non null records

# %%
a = data.isnull().sum()

# %%
a[a==0].count()
# Out:
# 19

# %% [markdown]
# #### Data types of columns

# %%
data.dtypes
# Out:
# Age                         float64
# Attrition                    object
# BusinessTravel               object
# Department                   object
# DistanceFromHome              int64
# EducationField               object
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# TotalWorkingYears             int64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# ...

# %% [markdown]
# #### Count of missing values for each column

# %%
a[a>0]
# Out:
# Age               24
# BusinessTravel    30
# Department         4
# EducationField    12
# Gender            45
# JobRole           10
# MaritalStatus     56
# Over18            54
# dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ## TASK - 2 :

# %% [markdown]
# ### Define a function that identifies the data type of columns as categorical or numerical. Separate the names of  categorical columns and numerical columns and save them in two different lists.

# %%
def dtypes_col(data):
    categorical = []
    numerical = []
    for i in data.columns:
        if data[i].nunique() > 10:
            numerical.append(i)
        else:
            categorical.append(i)
            
    return categorical, numerical

categorical, numerical = dtypes_col(data)

# %%
print(numerical)
print()
print(type(numerical))
# Out:
# ['Age', 'DistanceFromHome', 'EmployeeNumber', 'HourlyRate', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# <class 'list'>

# %%
print(categorical)
print()
print(type(categorical))
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance']
#
# <class 'list'>

# %% [markdown]
# #####

# %% [markdown]
# ## TASK - 3 :

# %% [markdown]
# ### Perform descriptive analysis of each categorical column (identified in Task 2) by defining a function to print the following information. 1) The number of categories (unique value) present a column. 2) The mode of column. 3) The missing values of a column.

# %%
def cat_info(a):
    if data[a].isnull().sum() > 0:
        mode_value = data[a].mode()[0]
        data[a].fillna(mode_value, inplace=True)

    print(f"The number of categories in {a} : {data[a].nunique()}")
    print(f"The mode of {a} : {data[a].mode()[0]}")
    print(f"Missing values in {a} are : {data[a].isnull().sum()}")

# %%
cat_info("Attrition")
# Out:
# The number of categories in Attrition : 2
# The mode of Attrition : No
# Missing values in Attrition are : 0

# %%
cat_info("BusinessTravel")
# Out:
# The number of categories in BusinessTravel : 3
# The mode of BusinessTravel : Travel_Rarely
# Missing values in BusinessTravel are : 0

# %%
cat_info("Department")
# Out:
# The number of categories in Department : 3
# The mode of Department : Research & Development
# Missing values in Department are : 0

# %%
cat_info("EducationField")
# Out:
# The number of categories in EducationField : 6
# The mode of EducationField : Life Sciences
# Missing values in EducationField are : 0

# %%
cat_info("EnvironmentSatisfaction")
# Out:
# The number of categories in EnvironmentSatisfaction : 4
# The mode of EnvironmentSatisfaction : 3
# Missing values in EnvironmentSatisfaction are : 0

# %%
cat_info("Gender")
# Out:
# The number of categories in Gender : 2
# The mode of Gender : Male
# Missing values in Gender are : 0

# %%
cat_info("JobInvolvement")
# Out:
# The number of categories in JobInvolvement : 4
# The mode of JobInvolvement : 3
# Missing values in JobInvolvement are : 0

# %%
cat_info("JobRole")
# Out:
# The number of categories in JobRole : 9
# The mode of JobRole : Sales Executive
# Missing values in JobRole are : 0

# %%
cat_info("JobSatisfaction")
# Out:
# The number of categories in JobSatisfaction : 4
# The mode of JobSatisfaction : 4
# Missing values in JobSatisfaction are : 0

# %%
cat_info("MaritalStatus")
# Out:
# The number of categories in MaritalStatus : 3
# The mode of MaritalStatus : Married
# Missing values in MaritalStatus are : 0

# %%
cat_info("NumCompaniesWorked")
# Out:
# The number of categories in NumCompaniesWorked : 10
# The mode of NumCompaniesWorked : 1
# Missing values in NumCompaniesWorked are : 0

# %%
cat_info("Over18")
# Out:
# The number of categories in Over18 : 1
# The mode of Over18 : Y
# Missing values in Over18 are : 0

# %%
cat_info("OverTime")
# Out:
# The number of categories in OverTime : 2
# The mode of OverTime : No
# Missing values in OverTime are : 0

# %%
cat_info("PerformanceRating")
# Out:
# The number of categories in PerformanceRating : 2
# The mode of PerformanceRating : 3
# Missing values in PerformanceRating are : 0

# %%
cat_info("RelationshipSatisfaction")
# Out:
# The number of categories in RelationshipSatisfaction : 4
# The mode of RelationshipSatisfaction : 3
# Missing values in RelationshipSatisfaction are : 0

# %%
cat_info("TrainingTimesLastYear")
# Out:
# The number of categories in TrainingTimesLastYear : 7
# The mode of TrainingTimesLastYear : 2
# Missing values in TrainingTimesLastYear are : 0

# %%
cat_info("WorkLifeBalance")
# Out:
# The number of categories in WorkLifeBalance : 4
# The mode of WorkLifeBalance : 3
# Missing values in WorkLifeBalance are : 0

# %% [markdown]
# ###

# %% [markdown]
# ## TASK - 4 :

# %% [markdown]
# ### Perform descriptive analysis on categorical columns with the help of univariate graphs/charts, as mentioned below:

# %% [markdown]
# #### Use the "Attrition" column to display the count of attrited and existing employees using a bar chart and percentage of attrited and exsisting employees using a pie chart.

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
ax[0].set_title("Count of Attrited & Existing Employees")                  
percentage = data["Attrition"].value_counts()         
labels = (data["Attrition"].value_counts().index).to_list()
sns.countplot(x = data["Attrition"], ax = ax[0])
plt.pie(percentage,labels = labels, explode = [0.05, 0.05],autopct= "%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : 84% of employees are retained, while 16% of employees have moved on.

# %% [markdown]
# ######

# %% [markdown]
# #### Use the "Business_Travel" column to display the employee count by the type of business travel using a bar chart and the employee percentage by the type of business travel using a pie chart.

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
ax[0].set_title("Count of Employees by Business Travel Types")                  
percentage = data["BusinessTravel"].value_counts()         
labels = (data["BusinessTravel"].value_counts().index).to_list()
sns.countplot(x = data["BusinessTravel"], ax = ax[0])
plt.pie(percentage,labels = labels,explode = [0.05, 0.05, 0.05], autopct= "%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : Majority of customers travel rarely and 10% of the customers do not prefer travelling.

# %% [markdown]
# ######

# %% [markdown]
# #### Use the "Department" column to display department_wise employee count using a bar chart and department-wise employee allocation percentage using a pie chart.

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
ax[0].set_title("Department-wise Employee Count")
percentage = data["Department"].value_counts()
labels = (data["Department"].value_counts().index).to_list()

sns.countplot(x=data["Department"], ax=ax[0])
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation = 45, horizontalalignment='right')
plt.pie(percentage,labels=labels, explode = [0.05, 0.05, 0.05], autopct= "%0.2f%%")

plt.show()

# %% [markdown]
# ### ***Interpretation : 65% of employees work in the Research and Development department, 30% in the Sales department, and the remaining employees are part of the Human Resources department.

# %% [markdown]
# ####

# %% [markdown]
# #### Use the "EducationField" column to display the education_field wise employee count using a bar chart and its percentage using a pie chart.

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))
ax[0].set_title("Education Field-wise Employee count")
percentage = (data["EducationField"].value_counts())
labels = (data["EducationField"].value_counts().index).to_list()

sns.countplot(x=data["EducationField"],ax=ax[0])
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation = 45, horizontalalignment='right')
plt.pie(percentage,labels=labels,explode = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03],autopct= "%0.2f%%")

plt.show()

# %% [markdown]
# ### ***Interpretation : The majority of employees are from the Life Science and Medical Education fields, constituting a significant portion of our workforce. Only 2% of employees belong to the Human Resources department, while the remaining workforce is distributed among the Marketing, Technical Degree, and other fields.

# %% [markdown]
# ###

# %% [markdown]
# #### Use the "EnvironmentSatisfaction" column dislpay the employee count by environment satisfaction score using a bar chart and display its percentage on the top of each bar.

# %%
def percentage(ax, count: "number of rows in data "):
    for bar in ax.patches:                                            
        percentage = f"{round((bar.get_height() / count) *100, 2)}%"  
                                                                           
        x = bar.get_x() + bar.get_width() /2                         
        y = bar.get_height()                                         
        ax.annotate(percentage, (x, y), va = "bottom", ha = "center")  
                                                                      
                                                                       
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,6))
ax.set_title("Employee Count by Environment Satisfaction")
ax = sns.countplot(x=data["EnvironmentSatisfaction"])
percentage(ax,len(data))

# %% [markdown]
# ### ***Interpretation : Approximately 60% of employees have an environment satisfaction scale ranging from 3 to 4, while the remaining employees fall within the 1 to 2 range.

# %% [markdown]
# ####

# %% [markdown]
# #### Use the "Gender" column to display the gender-wise employee count using a bar chart and display the corresponding percentage on the top of each bar.

# %%
fig, ax = plt.subplots(figsize=(5,6))
ax.set_title("Gender-wise Employee Count")
ax = sns.countplot(x=data["Gender"])
percentage(ax,len(data))

# %% [markdown]
# ### ***Interpretation :  The majority of our employees, constituting 60%, are male, while 40% are female.

# %% [markdown]
# ######

# %% [markdown]
# #### Use the "MaritalStatus" column to display the marital ststus-wise employee count using a bar chart and display the corresponding percentage on the top of each bar.

# %%
fig, ax = plt.subplots(figsize=(5,6))
ax.set_title("MaritalStatus-wise Employee Count")
ax = sns.countplot(x=data["MaritalStatus"])
percentage(ax,len(data))

# %% [markdown]
# ### ***Interpretation : Close to half of our employees, specifically 50%, are married. Another 30% of our workforce is comprised of single individuals, while the remaining 20% have experienced divorce.

# %% [markdown]
# ####

# %% [markdown]
# #### Use the"OverTime" colomn to display the percentage of employees who are working beyond their shift time using a pie chart.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_title("Over Time Pie Chart")

percentage = data["OverTime"].value_counts()
labels = (data["OverTime"].value_counts().index).tolist()

ax.pie(percentage, labels=labels, explode=[0.03, 0.03], autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ### ***Interpretation : The above chart shows that 28% of employees work beyond their regular work hours.

# %% [markdown]
# ######

# %% [markdown]
# #### Use the "PerformanceRating" column to display the performance rating-wise employee percentage using a pie chart.

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Performace Rating-wise Employee Count")

percentage = data["PerformanceRating"].value_counts()
labels = (data["PerformanceRating"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,explode=[0.03, 0.03],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : Most of the employees have a performance rating score of 3, constituting 85%, while the remaining 15% have a different rating.

# %% [markdown]
# #####

# %% [markdown]
# #### Use the "WorkLifeBalance" column to display the employee percentage by work-life balance rating using a pie chart.

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Work Life Balance Pie Chart")

percentage = data["WorkLifeBalance"].value_counts()
labels = (data["WorkLifeBalance"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,explode=[0.03, 0.03, 0.03, 0.03],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### *** Interpretation : Among our employees, 5% are experiencing the challenge of the worst work-life balance, while a notable 10% enjoy the benefits of the best work-life balance. The majority, comprising 60% of our workforce, maintains a good work-life balance.

# %% [markdown]
# ####

# %% [markdown]
# ### Analysis for all categorical column (as per note).

# %% [markdown]
# #### JobInvolvement

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Job Involvement Pie Chart")

percentage = data["JobInvolvement"].value_counts()
labels = (data["JobInvolvement"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,explode=[0.03, 0.03, 0.03, 0.03],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : Approximately 60% of our employees have a job involvement scale of 3,only 5% of employees possess a job involvement scale of 1.

# %% [markdown]
# ######

# %% [markdown]
# #### JobRole

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Job Role-wise count of employees")

percentage = data["JobRole"].value_counts()
labels = (data["JobRole"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,explode=[0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : Nearly 60% of the employees are assigned job roles as sales executives, research scientists, and laboratory technicians. The remaining 40% are part of various other departments within the organization.

# %% [markdown]
# ######

# %% [markdown]
# #### JobSatisfaction

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Job Satisfaction Pie Chart")

percentage = data["JobSatisfaction"].value_counts()
labels = (data["JobSatisfaction"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,explode=[0.03, 0.03, 0.03, 0.03],autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### *** Interpretation : 60% percent of the employees express satisfaction with their job, while the remaining 40% indicate a lower level of satisfaction.

# %% [markdown]
# ######

# %% [markdown]
# #### Over18

# %%
fig,ax = plt.subplots(figsize = (12,6))
ax.set_title("Employee Age pie chart")

percentage = data["Over18"].value_counts()
labels = (data["Over18"].value_counts().index).to_list()

ax.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ### ***Interpretation : All employees working with the company are over 18 years old.

# %% [markdown]
# ######

# %% [markdown]
# ## TASK - 5 :

# %% [markdown]
# ### Perform descriptive analysis of each numerical column by defining a function to print the following information. 1) The measures of central tendency (mean, median) , 2) The standard deviation of a column, 3) The missing values of a column 4) The skewness of a column. Perform the missing value treatment, if required.

# %%
def num_info(s):
    if data[s].isnull().sum() > 0:
        mean_value = data[s].mean()
        data[s].fillna(mean_value, inplace=True)

    print(f"The mean of {s} : {data[s].mean()} ")
    print(f"The median is {s} : {data[s].median()}")
    print(f"The Standard devivation of {s} : {data[s].std()}")
    print(f"Missing values in {s} are : {data[s].isnull().sum()}")
    print(f"The skewness of {s} : {data[s].skew()}")

# %%
num_info("Age")
# Out:
# The mean of Age : 36.93015214384509
# The median is Age : 36.0
# The Standard devivation of Age : 9.087051409165534
# Missing values in Age are : 0
# The skewness of Age : 0.4123972471547611

# %%
num_info("DistanceFromHome")
# Out:
# The mean of DistanceFromHome : 9.19251700680272
# The median is DistanceFromHome : 7.0
# The Standard devivation of DistanceFromHome : 8.106864435666084
# Missing values in DistanceFromHome are : 0
# The skewness of DistanceFromHome : 0.9581179956568269

# %%
num_info("EmployeeNumber")
# Out:
# The mean of EmployeeNumber : 1024.865306122449
# The median is EmployeeNumber : 1020.5
# The Standard devivation of EmployeeNumber : 602.024334847475
# Missing values in EmployeeNumber are : 0
# The skewness of EmployeeNumber : 0.016574019580105036

# %%
num_info("HourlyRate")
# Out:
# The mean of HourlyRate : 65.89115646258503
# The median is HourlyRate : 66.0
# The Standard devivation of HourlyRate : 20.329427593996158
# Missing values in HourlyRate are : 0
# The skewness of HourlyRate : -0.03231095290044942

# %%
num_info("MonthlyIncome")
# Out:
# The mean of MonthlyIncome : 6502.931292517007
# The median is MonthlyIncome : 4919.0
# The Standard devivation of MonthlyIncome : 4707.956783097995
# Missing values in MonthlyIncome are : 0
# The skewness of MonthlyIncome : 1.3698166808390662

# %%
num_info("TotalWorkingYears")
# Out:
# The mean of TotalWorkingYears : 11.279591836734694
# The median is TotalWorkingYears : 10.0
# The Standard devivation of TotalWorkingYears : 7.780781675515004
# Missing values in TotalWorkingYears are : 0
# The skewness of TotalWorkingYears : 1.1171718528128527

# %%
num_info("YearsAtCompany")
# Out:
# The mean of YearsAtCompany : 7.0081632653061225
# The median is YearsAtCompany : 5.0
# The Standard devivation of YearsAtCompany : 6.126525152403566
# Missing values in YearsAtCompany are : 0
# The skewness of YearsAtCompany : 1.7645294543422085

# %%
num_info("YearsInCurrentRole")
# Out:
# The mean of YearsInCurrentRole : 4.229251700680272
# The median is YearsInCurrentRole : 3.0
# The Standard devivation of YearsInCurrentRole : 3.6231370346706395
# Missing values in YearsInCurrentRole are : 0
# The skewness of YearsInCurrentRole : 0.9173631562908262

# %%
num_info("YearsSinceLastPromotion")
# Out:
# The mean of YearsSinceLastPromotion : 2.1877551020408164
# The median is YearsSinceLastPromotion : 1.0
# The Standard devivation of YearsSinceLastPromotion : 3.222430279137968
# Missing values in YearsSinceLastPromotion are : 0
# The skewness of YearsSinceLastPromotion : 1.9842899833524859

# %%
num_info("YearsWithCurrManager")
# Out:
# The mean of YearsWithCurrManager : 4.12312925170068
# The median is YearsWithCurrManager : 3.0
# The Standard devivation of YearsWithCurrManager : 3.5681361205404407
# Missing values in YearsWithCurrManager are : 0
# The skewness of YearsWithCurrManager : 0.8334509919918475

# %% [markdown]
# ######

# %% [markdown]
# ## TASK - 6 :

# %% [markdown]
# ### Perform descriptive analysis with the help of univariate graphs/charts for the following numerical columns.

# %% [markdown]
# #### Use the "Age" column to display age-wise employee count distribution using a histogram and a box plot.

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
ax[0].set_title("Box Plot")
ax[1].set_title("Histogram")
sns.histplot(x = data["Age"], ax = ax[1], color = "m")
sns.boxplot(x = data["Age"], ax = ax[0], color = "lightgreen") 
plt.show()

# %% [markdown]
# ### *** Interpretation : Most of the employees are in between 30 to 45 years of age.

# %% [markdown]
# ####

# %% [markdown]
# #### Use the "HourlyRate" column to display the hourly salary-wise employee count distribution using a histogram and a box plot.

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
ax[0].set_title("Box Plot")
ax[1].set_title("Histogram")
sns.histplot(x = data["HourlyRate"], ax = ax[1], color = "m")
sns.boxplot(x = data["HourlyRate"], ax = ax[0], color = "lightgreen") 
plt.show()

# %% [markdown]
# ### ***Interpretation : A normal distribution is observed in the relationship between hourly rates and the count of employees.

# %% [markdown]
# ######

# %% [markdown]
# #### Use the "MonthlyIncome" column to display the monthy salary-wise employee count using a histogram and a box plot.

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
ax[0].set_title("Box Plot")
ax[1].set_title("Histogram")
sns.histplot(x = data["MonthlyIncome"], ax = ax[1], color = "m")
sns.boxplot(x = data["MonthlyIncome"], ax = ax[0], color = "lightgreen") 
plt.show()

# %% [markdown]
# ### *** Interpretation : It looks like there might be outliers in the salary data, and a significant portion of employees appears to have salaries ranging from 3000 to 8000.
